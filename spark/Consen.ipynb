# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

spark = SparkSession.builder\
        .master("local[*]")\
        .appName("Movies")\
        .config("spark.ui.port", "4050")\
        .getOrCreate()

sc = SparkContext.getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://06ee36274c5b:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Movies</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
file_path = "/opt/workspace/data/movies.csv"
df = spark.read.csv(file_path, inferSchema=True, header=True)

# %%
df.show(10)
# Out:
# +-------+--------------------+----+--------------------+--------------------+--------------------+------+
# |     id|                name|date|             tagline|         description|              minute|rating|
# +-------+--------------------+----+--------------------+--------------------+--------------------+------+
# |1000001|              Barbie|2023|She's everything....|Barbie and Ken ar...|                 114|  3.86|
# |1000002|            Parasite|2019|Act like you own ...|All unemployed, K...|                 133|  4.56|
# |1000003|Everything Everyw...|2022|The universe is s...|An aging Chinese ...|                 140|   4.3|
# |1000004|          Fight Club|1999|Mischief. Mayhem....|"A ticking-time-b...| until an eccentr...|   139|
# |1000005|          La La Land|2016|Here's to the foo...|Mia, an aspiring ...|                 129|  4.09|
# |1000006|         Oppenheimer|2023|The world forever...|The story of J. R...|                 181|  4.23|
# |1000007|        Interstellar|2014|Mankind was born ...|The adventures of...|                 169|  4.35|
# |1000008|               Joker|2019|Put on a happy face.|During the 1980s,...|                 122|  3.85|
# |1000009|                Dune|2021|Beyond fear, dest...|Paul Atreides, a ...|                 155|   3.9|
# |1000010|        Pulp Fiction|1994|Just because you ...|A burger-loving h...|                 154|  4.26|
# +-------+--------------------+----+--------------------+--------------------+--------------------+------+
# only showing top 10 rows

# %%
df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- tagline: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- minute: string (nullable = true)
#  |-- rating: string (nullable = true)

# %%
df.columns
# Out:
# ['id', 'name', 'date', 'tagline', 'description', 'minute', 'rating']

# %%
df.describe().show()
# Out:
# 26/01/19 17:30:47 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 8:======================>                                  (8 + 12) / 20]
# +-------+----------------+------+--------------------+------------------+--------------------+--------------------+------------------+
# |summary|              id|  name|                date|           tagline|         description|              minute|            rating|
# +-------+----------------+------+--------------------+------------------+--------------------+--------------------+------------------+
# |  count|          941597|941597|              849691|            139446|              780759|              765498|            132985|
# |   mean|       1470799.0|   NaN|  1998.5219648035857| 914.0454545454545|    7.94454685666E12|   65.80042199502748|11.869323815532395|
# | stddev|271815.785046601|   NaN|  27.534743013524448|1086.0663645685643|2.969339172562304E13|  191.56365454369032| 55.26570277365232|
# |    min|         1000001|     !| . . . I Trust in...|            Cheezy|          "" he said|                    |                  |
# |    max|         1941597|🏳️‍🌈|                2031|                😨|🐝 + my + 🐝 + my...|” “There’s No Bus...|  ” “White & Nerdy|
# +-------+----------------+------+--------------------+------------------+--------------------+--------------------+------------------+

# %%
df.select(["name", "minute", "rating"]).show()
# Out:
# +--------------------+--------------------+------+
# |                name|              minute|rating|
# +--------------------+--------------------+------+
# |              Barbie|                 114|  3.86|
# |            Parasite|                 133|  4.56|
# |Everything Everyw...|                 140|   4.3|
# |          Fight Club| until an eccentr...|   139|
# |          La La Land|                 129|  4.09|
# |         Oppenheimer|                 181|  4.23|
# |        Interstellar|                 169|  4.35|
# |               Joker|                 122|  3.85|
# |                Dune|                 155|   3.9|
# |        Pulp Fiction|                 154|  4.26|
# |Spider-Man: Into ...| causing others f...|   117|
# |            Whiplash|                 107|  4.43|
# |          The Batman|                 177|  3.98|
# |             Get Out|                 104|  4.16|
# |          Knives Out|                 131|  3.99|
# |           Midsommar|                 147|  3.78|
# |     The Dark Knight|                 152|  4.47|
# |           Inception| the implantation...|   148|
# |            Saltburn|                 131|  3.43|
# |         Poor Things|                 142|  4.05|
# +--------------------+--------------------+------+
# only showing top 20 rows

# %%
df.filter(df.rating ==1).show()
# Out:
# +-------+--------------------+----+--------------------+--------------------+------+------+
# |     id|                name|date|             tagline|         description|minute|rating|
# +-------+--------------------+----+--------------------+--------------------+------+------+
# |1000733|      Justice League|2017|                NULL|Fuelled by his re...|   120|  1.93|
# |1000796|          Madame Web|2024|Her web connects ...|Forced to confron...|   116|  1.49|
# |1000905|             Morbius|2022|The line between ...|Dangerously ill w...|   105|   1.6|
# |1001293|Fifty Shades of Grey|2015|    Are you curious?|When college seni...|   125|  1.75|
# |1001316|   The Kissing Booth|2018|She can tell her ...|When teenager Ell...|   105|  1.59|
# |1001381|      Batman & Robin|1997|Strength. Courage...|Along with crime-...|   125|  1.84|
# |1001460|Texas Chainsaw Ma...|2022|The face of madne...|In this sequel, i...|    83|  1.83|
# |1001559|Space Jam: A New ...|2021| Welcome to the Jam!|When LeBron and h...|   115|  1.84|
# |1001746|                Cats|2019|   You will believe.|A tribe of cats c...|   110|  1.27|
# |1001800|       Green Lantern|2011|In our darkest ho...|For centuries, a ...|   114|  1.56|
# |1001918|  The Last Airbender|2010|Four nations, one...|The story follows...|   103|  1.07|
# |1002027|      Fantastic Four|2015|   Change is coming.|Four young outsid...|   100|  1.32|
# |1002040|               After|2019|After your first,...|Tessa Young is a ...|   106|  1.52|
# |1002172|            Moonfall|2022|Humanity will fac...|A mysterious forc...|   131|  1.92|
# |1002187| The Kissing Booth 2|2020|Rules can be brok...|With college deci...|   132|  1.44|
# |1002205|       Miller's Girl|2024|Write what you want.|A precocious youn...|    93|  1.79|
# |1002223|     The Emoji Movie|2017|  Not easy being meh|Gene, a multi-exp...|    86|  1.23|
# |1002246|          Death Note|2017|                NULL|A young man comes...|   101|  1.49|
# |1002278|Transformers: The...|2017|For one world to ...|Autobots and Dece...|   154|  1.85|
# |1002334|       He's All That|2021|It's his turn for...|To get revenge on...|    91|  1.21|
# +-------+--------------------+----+--------------------+--------------------+------+------+
# only showing top 20 rows
