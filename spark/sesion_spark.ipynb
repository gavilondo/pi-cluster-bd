# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("movies")
    .master("spark://spark-master:7077")
    .getOrCreate()
)

spark
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/31 12:08:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7c3789e19040:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>movies</code></dd>
#             </dl>
#         </div>
#
#             </div>
# ...

# %%
file_path = "/opt/workspace/data/actors.csv"
df = spark.read.csv(file_path, inferSchema=True, header=True)

# %%
df.show(10)
# Out:
# +-------+-----------------+------+
# |     id|             name|  role|
# +-------+-----------------+------+
# |1000001|    Margot Robbie|Barbie|
# |1000001|     Ryan Gosling|   Ken|
# |1000001|  America Ferrera|Gloria|
# |1000001|Ariana Greenblatt| Sasha|
# |1000001|         Issa Rae|Barbie|
# |1000001|    Kate McKinnon|Barbie|
# |1000001|  Alexandra Shipp|Barbie|
# |1000001|      Emma Mackey|Barbie|
# |1000001|         Hari Nef|Barbie|
# |1000001|    Sharon Rooney|Barbie|
# +-------+-----------------+------+
# only showing top 10 rows
