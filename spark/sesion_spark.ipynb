# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("movies")
    .master("spark://spark-master:7077")
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://94ce459eba5f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>movies</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv(
    "hdfs://namenode:9000/data/actors.csv",
    header=True,
    inferSchema=True
)

df.show(10)
# Out:
# [Stage 8:>                                                          (0 + 4) / 4]
# +-------+-----------------+------+
# |     id|             name|  role|
# +-------+-----------------+------+
# |1000001|    Margot Robbie|Barbie|
# |1000001|     Ryan Gosling|   Ken|
# |1000001|  America Ferrera|Gloria|
# |1000001|Ariana Greenblatt| Sasha|
# |1000001|         Issa Rae|Barbie|
# |1000001|    Kate McKinnon|Barbie|
# |1000001|  Alexandra Shipp|Barbie|
# |1000001|      Emma Mackey|Barbie|
# |1000001|         Hari Nef|Barbie|
# |1000001|    Sharon Rooney|Barbie|
# +-------+-----------------+------+
# only showing top 10 rows
